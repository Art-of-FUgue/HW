# %%
import scipy as sp
import numpy as np
import math as math
import os
import pylab as plb
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd
import csv
from scipy.odr import *
import random

# %%
# graphene
year = np.array([2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])
graphene_publication = np.array([4948,7504,10141,12724,15646,18211,20343,21038,23843,25530,25653])
carbon_publication = np.array([8667,9637,9622,10146,10259,10246,10557,10285,10782,11470,11453])
MoS2_publication = np.array([241,269,412,802,1283,1740,2200,2397,3058,3464,3576])
plt.plot(year, graphene_publication)
plt.plot(year, carbon_publication)
plt.plot(year, MoS2_publication)
plt.title("Number of publications")
plt.xlabel("Year")
plt.ylabel("Numbers of publication")
plt.legend(['graphene', 'carbon nanotube', 'MoS2'])
